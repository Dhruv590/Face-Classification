# %%
import cv2
import numpy as np
import os
import sys
import subprocess
import shutil

# %%
def is_valid_image_file(filename):
    """
    Check if the file is a valid image format for processing (excluding .heic).
    """
    valid_extensions = ['.jpg', '.jpeg', '.png']
    return any(filename.lower().endswith(ext) for ext in valid_extensions)

# %%
def detect_faces(input_dir, output_dir):
    # Load the pre-trained Haar Cascade model for face detection
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt2.xml')

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Iterate over subdirectories in the main directory
    for subdir in os.listdir(input_dir):
        subdir_path = os.path.join(input_dir, subdir)
        output_subdir = os.path.join(output_dir, subdir)
        os.makedirs(output_subdir, exist_ok=True)

        print("Processing directory:", subdir_path)

        # Iterate over files in the current subdirectory
        for filename in os.listdir(subdir_path):
            image_path = os.path.join(subdir_path, filename)

            try:
                image = cv2.imread(image_path)

                if image is not None:
                    # Convert the image to grayscale for face detection
                    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                    faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
                    
                    for i, (x, y, w, h) in enumerate(faces):
                        face_region = image[y:y+h, x:x+w]
                        resized_face = cv2.resize(face_region, (224, 224))
                        output_filename = f"{os.path.splitext(filename)[0]}_face{i}{os.path.splitext(filename)[1]}"
                        output_path = os.path.join(output_subdir, output_filename)

                        cv2.imwrite(output_path, resized_face)
                        print(f"Saved face: {output_path}")
                else:
                    print(f"Error loading image: {image_path}")
            except Exception as e:
                print(f"An error occurred while processing {image_path}: {str(e)}")

    print("Face extraction completed.")

# %%
def enhance_contrast(img, intensity):
    lab_img = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab_img)
    l = np.clip(cv2.add(l, intensity), 0, 255)
    merged_lab = cv2.merge((l, a, b))
    gray_img = cv2.cvtColor(cv2.cvtColor(merged_lab, cv2.COLOR_LAB2BGR), cv2.COLOR_BGR2GRAY)
    return gray_img

def enhance_brightness(img, intensity):
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv_img)
    v = np.clip(cv2.add(v, intensity), 0, 255)
    merged_hsv = cv2.merge((h, s, v))
    gray_img = cv2.cvtColor(cv2.cvtColor(merged_hsv, cv2.COLOR_HSV2BGR), cv2.COLOR_BGR2GRAY)
    return gray_img

def process_images(source, destination):
    """
    Process images by applying various transformations and saving them.
    """
    if not os.path.exists(destination):
        os.makedirs(destination)

    for root_dir, _, filenames in os.walk(source):
        dest_path = os.path.join(destination, os.path.relpath(root_dir, source))
        os.makedirs(dest_path, exist_ok=True)

        for file in filenames:
            if not is_valid_image_file(file):
                continue
    if not os.path.exists(destination):
        os.makedirs(destination)

    for root_dir, _, filenames in os.walk(source):
        dest_path = os.path.join(destination, os.path.relpath(root_dir, source))
        os.makedirs(dest_path, exist_ok=True)

        for file in filenames:
            if file.lower().endswith((".jpg", ".png")):
                img_path = os.path.join(root_dir, file)
                img = cv2.imread(img_path)

                if img is None or img.shape[-1] != 3:
                    continue

                denoised_img = cv2.fastNlMeansDenoisingColored(img, None, 10, 10, 7, 21)

                gray_img = cv2.cvtColor(denoised_img, cv2.COLOR_BGR2GRAY)
                blur_img = cv2.GaussianBlur(gray_img, (5, 5), 0)
                bright_img = enhance_brightness(denoised_img, 50)
                dark_img = enhance_brightness(denoised_img, -50)
                high_contrast_img = enhance_contrast(denoised_img, 50)
                low_contrast_img = enhance_contrast(denoised_img, -50)
                mirror_img = cv2.flip(gray_img, 1)

                # Saving the processed images
                cv2.imwrite(os.path.join(dest_path, f"{file.split('.')[0]}_gray.jpg"), gray_img)
                cv2.imwrite(os.path.join(dest_path, f"{file.split('.')[0]}_blur.jpg"), blur_img)
                cv2.imwrite(os.path.join(dest_path, f"{file.split('.')[0]}_bright.jpg"), bright_img)
                cv2.imwrite(os.path.join(dest_path, f"{file.split('.')[0]}_dark.jpg"), dark_img)
                cv2.imwrite(os.path.join(dest_path, f"{file.split('.')[0]}_high_contrast.jpg"), high_contrast_img)
                cv2.imwrite(os.path.join(dest_path, f"{file.split('.')[0]}_low_contrast.jpg"), low_contrast_img)
                cv2.imwrite(os.path.join(dest_path, f"{file.split('.')[0]}_mirror.jpg"), mirror_img)

# %%
def main(input_dir, output_dir):
    # Load the pre-trained Haar Cascade model for face detection
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt2.xml')

    face_out_dir = os.path.join(output_dir, "face/")
    combined_out_dir = os.path.join(output_dir, "combined/")
    aug_out_dir = os.path.join(output_dir, "augment/")
    final_out_dir = os.path.join(output_dir, "train/")

    # Detect faces and save in face_out_dir
    detect_faces(input_dir, face_out_dir)

    # Process the detected faces for data augmentation and save in aug_out_dir
    process_images(face_out_dir, aug_out_dir)

    # Optionally, combine original and augmented data
    # This step is optional and depends on whether you want to combine the original processed images with the augmented ones
    # If so, uncomment the next two lines
    # for filename in os.listdir(aug_out_dir):
    #     shutil.copy(os.path.join(aug_out_dir, filename), combined_out_dir)

    # Move augmented data to final directory
    if os.path.exists(aug_out_dir) and os.listdir(aug_out_dir):
        shutil.move(aug_out_dir, final_out_dir)
        print("Moved augmented data to final directory.")
    else:
        print(f"Augmented directory {aug_out_dir} does not exist or is empty.")
    print("Final output directory:", final_out_dir)

# %%
input_directory = "/content/drive/MyDrive/COEN 240/Release-2"
output_directory = "/content/drive/MyDrive/COEN 240"

# Call the main function 
main(input_directory, output_directory)
# Out:
# Processing directory: COEN240/Release-2/Kimsong
# Saved face: COEN240/face/Kimsong/Capture7_face0.PNG
# Saved face: COEN240/face/Kimsong/Capture6_face0.PNG
# Saved face: COEN240/face/Kimsong/Capture4_face0.PNG
# Saved face: COEN240/face/Kimsong/Capture1_face0.PNG
# Saved face: COEN240/face/Kimsong/Capture2_face0.PNG
# Saved face: COEN240/face/Kimsong/Capture8_face0.PNG
# Saved face: COEN240/face/Kimsong/Capture_face0.PNG
# Saved face: COEN240/face/Kimsong/Screenshot 2023-09-26 at 12.40.58 PM_face0.png
# Error loading image: COEN240/Release-2/Kimsong/IMG_8546.HEIC
# Processing directory: COEN240/Release-2/Anirudh
# Saved face: COEN240/face/Anirudh/0926-ClassPhotos_face0.png
# Error loading image: COEN240/Release-2/Anirudh/IMG_8564.HEIC
# Saved face: COEN240/face/Anirudh/Screenshot 2023-10-21 at 9.57.15 PM_face0.png
# Saved face: COEN240/face/Anirudh/9-28_face0.png
# Saved face: COEN240/face/Anirudh/0921-ClassPhotos _face0.png
# Saved face: COEN240/face/Anirudh/0921-ClassPhotos _face1.png
# Saved face: COEN240/face/Anirudh/Screenshot 2023-10-21 at 9.59.56 PM_face0.png
# Saved face: COEN240/face/Anirudh/0919-ClassPhotos_face0.png
# Processing directory: COEN240/Release-2/Kaiyue
# Error loading image: COEN240/Release-2/Kaiyue/IMG_8549.HEIC
# Saved face: COEN240/face/Kaiyue/cf13dd08962756ce9ec28ecc166ae68_face0.png
# Saved face: COEN240/face/Kaiyue/de07e4560e8fdb6d3e6087503d8bb48_face0.png
# Processing directory: COEN240/Release-2/Xinze
# Saved face: COEN240/face/Xinze/1696527400.594572_face0.jpg
# Saved face: COEN240/face/Xinze/1695317201.98072_face0.jpg
# Saved face: COEN240/face/Xinze/1695747808.967338_face0.jpg
# Saved face: COEN240/face/Xinze/1697775155.694821_face0.jpg
# Saved face: COEN240/face/Xinze/1695934956.354838_face0.jpg
# Error loading image: COEN240/Release-2/Xinze/IMG_8536.HEIC
# Saved face: COEN240/face/Xinze/1697606291.953927_face0.jpg
# Saved face: COEN240/face/Xinze/1695162656.439209_face0.jpg
# Saved face: COEN240/face/Xinze/1696355465.765733_face0.jpg
# Processing directory: COEN240/Release-2/Wagawaththa
# Saved face: COEN240/face/Wagawaththa/Photo Amarasinghe 1019_face0.PNG
# Saved face: COEN240/face/Wagawaththa/Photo Amarasinghe 0926_face0.PNG
# Error loading image: COEN240/Release-2/Wagawaththa/IMG_8557.HEIC
# Saved face: COEN240/face/Wagawaththa/PhotoAmarasinghe1003_face0.PNG
# Saved face: COEN240/face/Wagawaththa/PhotoAmarasinghe1005_face0.PNG
# Saved face: COEN240/face/Wagawaththa/Photo Amarasinghe 0928_face0.PNG
# Processing directory: COEN240/Release-2/Shreya Chinthala
# Saved face: COEN240/face/Shreya Chinthala/Screenshot 2023-10-05 at 1.04.02 PM_face0.png
# Saved face: COEN240/face/Shreya Chinthala/0921_face0.png
# Error loading image: COEN240/Release-2/Shreya Chinthala/IMG_8558.HEIC
# Saved face: COEN240/face/Shreya Chinthala/Screenshot 2023-10-04 at 3.53.15 PM_face0.png
# Saved face: COEN240/face/Shreya Chinthala/Screenshot 2023-09-26 at 6.47.49 PM_face0.png
# Saved face: COEN240/face/Shreya Chinthala/Screenshot 2023-09-23 at 7.49.52 PM_face0.png
# Saved face: COEN240/face/Shreya Chinthala/Screenshot 2023-10-18 at 1.32.53 PM_face0.png
# Saved face: COEN240/face/Shreya Chinthala/Screenshot 2023-09-29 at 10.15.25 AM_face0.png
# Saved face: COEN240/face/Shreya Chinthala/Screenshot 2023-10-19 at 7.16.50 PM_face0.png
# Processing directory: COEN240/Release-2/Manya
# Saved face: COEN240/face/Manya/Screenshot 2023-09-24 at 3.04.30 PM_face0.png
# Error loading image: COEN240/Release-2/Manya/IMG_8544.HEIC
# Saved face: COEN240/face/Manya/Screenshot 2023-10-19 at 3.44.32 PM_face0.png
# Saved face: COEN240/face/Manya/Screenshot 2023-10-03 at 11.02.17 AM_face0.png
# Saved face: COEN240/face/Manya/Screenshot 2023-09-26 at 11.12.05 AM_face0.png
# Saved face: COEN240/face/Manya/Screenshot 2023-09-28 at 11.16.30 AM_face0.png
# Saved face: COEN240/face/Manya/Screenshot 2023-09-24 at 3.02.28 PM_face0.png
# Saved face: COEN240/face/Manya/Screenshot 2023-10-19 at 10.12.34 AM_face0.png
# Processing directory: COEN240/Release-2/Divyanth
# Error loading image: COEN240/Release-2/Divyanth/IMG_8565.HEIC
# Saved face: COEN240/face/Divyanth/Image 9-19-23 at 5.48 PM_face0.jpeg
# Saved face: COEN240/face/Divyanth/Image 9-27-23 at 12.34 AM_face0.jpeg
# Saved face: COEN240/face/Divyanth/Image 10-5-23 at 7.28 PM_face0.jpeg
# Saved face: COEN240/face/Divyanth/Image 10-18-23 at 11.08 PM_face0.jpeg
# Saved face: COEN240/face/Divyanth/Image 9-21-23 at 1.52 PM_face0.jpeg
# Saved face: COEN240/face/Divyanth/Image 9-29-23 at 12.39 AM_face0.jpeg
# Saved face: COEN240/face/Divyanth/Image 10-19-23 at 7.29 PM_face0.jpeg
# Saved face: COEN240/face/Divyanth/Image 10-4-23 at 10.19 PM_face0.jpeg
# Processing directory: COEN240/Release-2/Shreya Devendra
# Saved face: COEN240/face/Shreya Devendra/IMG_8481_face0.jpeg
# Saved face: COEN240/face/Shreya Devendra/Shreya Bisen_face0.jpeg
# Error loading image: COEN240/Release-2/Shreya Devendra/IMG_8554.HEIC
# Saved face: COEN240/face/Shreya Devendra/Shreya Bisen (09_26)_face0.jpeg
# Saved face: COEN240/face/Shreya Devendra/Shreya Bisen (09_21) (1)_face0.jpeg
# Saved face: COEN240/face/Shreya Devendra/IMG_8374_face0.jpeg
# Saved face: COEN240/face/Shreya Devendra/Shreya Bisen (09_28)_face0.jpeg
# Saved face: COEN240/face/Shreya Devendra/Shreya Bisen (09_28)_face1.jpeg
# Saved face: COEN240/face/Shreya Devendra/IMG_8466_face0.jpeg
# Saved face: COEN240/face/Shreya Devendra/IMG_8406_face0.jpeg
# Processing directory: COEN240/Release-2/Samyuktha
# Saved face: COEN240/face/Samyuktha/Samyuktha-Venkatesan-ML-class_face0.PNG
# Error loading image: COEN240/Release-2/Samyuktha/IMG_8559.HEIC
# Saved face: COEN240/face/Samyuktha/Samyukth-Venkatesan-ML-class-9_face0.PNG
# Saved face: COEN240/face/Samyuktha/Samyuktha-Venkatesan-class-6_face0.PNG
# Saved face: COEN240/face/Samyuktha/Samyuktha-Venkatesan-class-4_face0.PNG
# Saved face: COEN240/face/Samyuktha/Samyuktha-Venkatesan-class-5_face0.PNG
# Saved face: COEN240/face/Samyuktha/Samyuktha-Venkatesan-class-2_face0.PNG
# Saved face: COEN240/face/Samyuktha/Samyuktha-Venkatesan-class-3_face0.PNG
# Processing directory: COEN240/Release-2/Shreyas
# Saved face: COEN240/face/Shreyas/Screenshot 2023-10-18 at 4.31.19 PM_face0.png
# Saved face: COEN240/face/Shreyas/IMG_8253_shreyas_face0.jpeg
# Saved face: COEN240/face/Shreyas/IMG_8253_shreyas_face1.jpeg
# Saved face: COEN240/face/Shreyas/IMG_8206_Shreyas_face0.jpeg
# Error loading image: COEN240/Release-2/Shreyas/IMG_8563.HEIC
# Saved face: COEN240/face/Shreyas/IMG_8195_Shreyas__face0.jpg
# Saved face: COEN240/face/Shreyas/Screenshot 2023-10-06 at 12.28.55 PM_face0.png
# Saved face: COEN240/face/Shreyas/IMG_8378_shreyas_HC_face0.jpeg
# Saved face: COEN240/face/Shreyas/Screenshot 2023-10-19 at 11.06.33 PM_face0.png
# Processing directory: COEN240/Release-2/Varshit
# Saved face: COEN240/face/Varshit/1698075546.0068212_face0.jpg
# Error loading image: COEN240/Release-2/Varshit/IMG_8562.HEIC
# Saved face: COEN240/face/Varshit/1696530528.8246_face0.jpg
# Saved face: COEN240/face/Varshit/1698075473.139697_face0.jpg
# Saved face: COEN240/face/Varshit/Image 10-2-23 at 2.23 PM_face0.jpeg
# Saved face: COEN240/face/Varshit/Image 9-23-23 at 12.10 PM_face0.jpeg
# Saved face: COEN240/face/Varshit/Image 10-4-23 at 1.55 PM_face0.jpeg
# Saved face: COEN240/face/Varshit/day-1_face0.png
# Saved face: COEN240/face/Varshit/Image 9-27-23 at 12.29 AM_face0.jpeg
# Processing directory: COEN240/Release-2/Chen
# Saved face: COEN240/face/Chen/Screenshot 2023-10-01 at 10.03.05_face0.png
# Saved face: COEN240/face/Chen/Screenshot 2023-10-04 at 23.35.45_face0.png
# Saved face: COEN240/face/Chen/chenli1_face0.jpg
# Saved face: COEN240/face/Chen/chenli2_face0.jpg
# Saved face: COEN240/face/Chen/chenli2_face1.jpg
# Saved face: COEN240/face/Chen/Screenshot 2023-10-06 at 23.49.06_face0.png
# Saved face: COEN240/face/Chen/Screenshot 2023-10-21 at 10.43.35_face0.png
# Saved face: COEN240/face/Chen/Screenshot 2023-10-21 at 10.39.00_face0.png
# Error loading image: COEN240/Release-2/Chen/IMG_8540.HEIC
# Saved face: COEN240/face/Chen/chenli_3_face0.jpg
# Processing directory: COEN240/Release-2/Peiqi
# Error loading image: COEN240/Release-2/Peiqi/IMG_8545.HEIC
# Saved face: COEN240/face/Peiqi/1696530892.834202_face0.jpg
# Saved face: COEN240/face/Peiqi/Screenshot 2023-09-25 at 12.34.27_face0.png
# Saved face: COEN240/face/Peiqi/1696530878.9673119_face0.jpg
# Saved face: COEN240/face/Peiqi/Screenshot 2023-09-25 at 12.35.44_face0.png
# Saved face: COEN240/face/Peiqi/1697605386.8055348_face0.jpg
# Saved face: COEN240/face/Peiqi/Screenshot 2023-10-22 at 16.01.33_face0.png
# Processing directory: COEN240/Release-2/Aparnaa
# Saved face: COEN240/face/Aparnaa/IMG_8208 (1)_face0.jpeg
# Error loading image: COEN240/Release-2/Aparnaa/IMG_8553.HEIC
# Saved face: COEN240/face/Aparnaa/IMG_8198 (1)_face0.jpeg
# Saved face: COEN240/face/Aparnaa/IMG_8277 (1)_face0.jpeg
# Saved face: COEN240/face/Aparnaa/IMG_8244 (1)_face0.jpeg
# Saved face: COEN240/face/Aparnaa/IMG_8409 (1)_face0.jpeg
# Saved face: COEN240/face/Aparnaa/IMG_8469 (1)_face0.jpeg
# Saved face: COEN240/face/Aparnaa/IMG_8382 (1) copy_face0.jpeg
# Processing directory: COEN240/Release-2/Qihui
# Saved face: COEN240/face/Qihui/qihui_face0.jpg
# Saved face: COEN240/face/Qihui/1697724731716_face0.jpg
# Error loading image: COEN240/Release-2/Qihui/IMG_8537.HEIC
# Saved face: COEN240/face/Qihui/1697823340664_face0.jpg
# Saved face: COEN240/face/Qihui/qihui-1_face0.jpg
# Saved face: COEN240/face/Qihui/1696545426962_face0.jpg
# Processing directory: COEN240/Release-2/Madhuri
# Saved face: COEN240/face/Madhuri/IMG_8481-Madhuri Sharma-cropped_face0.jpeg
# Saved face: COEN240/face/Madhuri/IMG_8204-Madhuri Sharma-cropped_face0.jpeg
# Saved face: COEN240/face/Madhuri/IMG_8465-Madhuri Sharma-cropped_face0.jpeg
# Saved face: COEN240/face/Madhuri/IMG_8272-Madhuri Sharma-cropped_face0.jpeg
# Error loading image: COEN240/Release-2/Madhuri/IMG_8560.HEIC
# Saved face: COEN240/face/Madhuri/IMG_8244-Madhuri Sharma-cropped_face0.jpeg
# Saved face: COEN240/face/Madhuri/IMG_8374-Madhuri Sharma-cropped_face0.jpeg
# Saved face: COEN240/face/Madhuri/IMG_8193-Madhuri Sharma-cropped_face0.jpeg
# Saved face: COEN240/face/Madhuri/IMG_8403-Madhuri Sharma-cropped_face0.jpeg
# Saved face: COEN240/face/Madhuri/IMG_8482-Madhuri Sharma-cropped_face0.jpeg
# Processing directory: COEN240/Release-2/Shubham
# Saved face: COEN240/face/Shubham/IMG_8487_face0.jpeg
# Saved face: COEN240/face/Shubham/IMG_8409_face0.jpeg
# Error loading image: COEN240/Release-2/Shubham/IMG_8548.HEIC
# Saved face: COEN240/face/Shubham/IMG_8193_face0.jpeg
# Saved face: COEN240/face/Shubham/IMG_8248_face0.jpeg
# Saved face: COEN240/face/Shubham/IMG_8208_face0.jpeg
# Saved face: COEN240/face/Shubham/IMG_8379_face0.jpeg
# Saved face: COEN240/face/Shubham/IMG_8276_face0.jpeg
# Saved face: COEN240/face/Shubham/IMG_8471_face0.jpeg
# Processing directory: COEN240/Release-2/Griffin
# Error loading image: COEN240/Release-2/Griffin/IMG_8532.HEIC
# Saved face: COEN240/face/Griffin/Griffin_face0.jpg
# Saved face: COEN240/face/Griffin/Griffin-1_face0.jpeg
# Saved face: COEN240/face/Griffin/Griffin-2_face0.jpeg
# Saved face: COEN240/face/Griffin/Griffin-3_face0.jpeg
# Saved face: COEN240/face/Griffin/Griffin_face0.jpeg
# Processing directory: COEN240/Release-2/Yash
# Saved face: COEN240/face/Yash/IMG_8406 (1)_face0.jpeg
# Saved face: COEN240/face/Yash/IMG_8243_face0.jpeg
# Saved face: COEN240/face/Yash/IMG_8207_face0.jpeg
# Error loading image: COEN240/Release-2/Yash/IMG_8561.HEIC
# Saved face: COEN240/face/Yash/IMG_8375_face0.jpeg
# Saved face: COEN240/face/Yash/IMG_8271_face0.jpeg
# Saved face: COEN240/face/Yash/Yash Suryavanshi; C1-1_face0.png
# Saved face: COEN240/face/Yash/IMG_8481-EDIT_face0.jpg
# Saved face: COEN240/face/Yash/IMG_8465-EDIT_face0.jpg
# Processing directory: COEN240/Release-2/Pooja
# Saved face: COEN240/face/Pooja/ML image class5_face0.jpeg
# Saved face: COEN240/face/Pooja/ML image class2_face0.jpeg
# Saved face: COEN240/face/Pooja/IMG_Sep19_face0.jpeg
# Saved face: COEN240/face/Pooja/IMG_Sep19_face1.jpeg
# Error loading image: COEN240/Release-2/Pooja/IMG_8547.HEIC
# Saved face: COEN240/face/Pooja/Pooja.19Sep_face0.jpeg
# Saved face: COEN240/face/Pooja/ML image class6_face0.jpeg
# Processing directory: COEN240/Release-2/Husain
# Saved face: COEN240/face/Husain/IMG_8254_face0.jpeg
# Saved face: COEN240/face/Husain/IMG_8274_face0.jpeg
# Saved face: COEN240/face/Husain/IMG_8214_face0.jpeg
# Error loading image: COEN240/Release-2/Husain/IMG_8534.HEIC
# Saved face: COEN240/face/Husain/IMG_8196_face0.jpeg
# Saved face: COEN240/face/Husain/IMG_8470_face0.jpeg
# Saved face: COEN240/face/Husain/IMG_8410_face0.jpeg
# Saved face: COEN240/face/Husain/IMG_8484_face0.jpeg
# Processing directory: COEN240/Release-2/Huiyu
# Saved face: COEN240/face/Huiyu/Screenshot 2023-10-03 at 2.21.06 PM_face0.png
# Saved face: COEN240/face/Huiyu/Screenshot 2023-10-23 at 12.16.58 PM_face0.png
# Error loading image: COEN240/Release-2/Huiyu/IMG_8539.HEIC
# Saved face: COEN240/face/Huiyu/Screenshot 2023-09-21 at 10.15.21 AM_face0.png
# Saved face: COEN240/face/Huiyu/Screenshot 2023-09-27 at 11.13.47 PM_face0.png
# Saved face: COEN240/face/Huiyu/Screenshot 2023-09-28 at 5.06.11 PM_face0.png
# Saved face: COEN240/face/Huiyu/Screenshot 2023-10-18 at 9.28.38 PM_face0.png
# Saved face: COEN240/face/Huiyu/Screenshot 2023-10-05 at 11.47.42 PM_face0.png
# Saved face: COEN240/face/Huiyu/Huiyu Liu_face0.png
# Processing directory: COEN240/Release-2/Wei
# Saved face: COEN240/face/Wei/bd32c1e7d0b8ac19980b003ef9c370a5_face0.png
# Saved face: COEN240/face/Wei/65d873090a96687342eba796ddf00c8e_face0.png
# Saved face: COEN240/face/Wei/d095f80ed097b6e03da6d2d949794536_face0.png
# Error loading image: COEN240/Release-2/Wei/IMG_8550.HEIC
# Saved face: COEN240/face/Wei/a68ee9edfdcb5676e55c0cba79e27db2_face0.png
# Saved face: COEN240/face/Wei/b853cba55a7e86d3741a3dedbc854fbd_face0.png
# Processing directory: COEN240/Release-2/Yutong
# Saved face: COEN240/face/Yutong/1696298036.481302_face0.jpg
# Saved face: COEN240/face/Yutong/1696544946.764776_face0.jpg
# Error loading image: COEN240/Release-2/Yutong/IMG_8555.HEIC
# Saved face: COEN240/face/Yutong/1696298049.68504_face0.jpg
# Processing directory: COEN240/Release-2/Zhiyu
# Saved face: COEN240/face/Zhiyu/1695929605.547509_face0.jpg
# Saved face: COEN240/face/Zhiyu/1696359741.164813_face0.jpg
# Saved face: COEN240/face/Zhiyu/1695162450.621253_face0.jpg
# Saved face: COEN240/face/Zhiyu/1695316397.687358_face0.jpg
# Saved face: COEN240/face/Zhiyu/1695316397.687358_face1.jpg
# Saved face: COEN240/face/Zhiyu/1695747433.1378431_face0.jpg
# Saved face: COEN240/face/Zhiyu/1697755363.861001_face0.jpg
# Saved face: COEN240/face/Zhiyu/1696527526.06545_face0.jpg
# Error loading image: COEN240/Release-2/Zhiyu/IMG_8531.HEIC
# Saved face: COEN240/face/Zhiyu/1697605572.581781_face0.jpg
# Processing directory: COEN240/Release-2/Zexin
# Saved face: COEN240/face/Zexin/IMG11_8271_face0.jpeg
# Saved face: COEN240/face/Zexin/08fa8c26399ffb5104e86a8ad75928e_face0.png
# Saved face: COEN240/face/Zexin/a01ebd33b10bdd09bc33f9d7831d3cc_face0.png
# Saved face: COEN240/face/Zexin/12413_face0.png
# Saved face: COEN240/face/Zexin/39a3bb589938f6ad58251f0b701c6f3_face0.png
# Error loading image: COEN240/Release-2/Zexin/IMG_8530.HEIC
# Saved face: COEN240/face/Zexin/IMaaaG_8246_face0.jpeg
# Saved face: COEN240/face/Zexin/2_face0.png
# Saved face: COEN240/face/Zexin/addcd37bc34128016c9d759b98f64ef_face0.png
# Processing directory: COEN240/Release-2/Yuhang
# Saved face: COEN240/face/Yuhang/week3-1_face0.png
# Saved face: COEN240/face/Yuhang/week1-2_face0.png
# Saved face: COEN240/face/Yuhang/week3-2_face0.png
# Saved face: COEN240/face/Yuhang/week5-1_face0.png
# Saved face: COEN240/face/Yuhang/week5-2_face0.png
# Error loading image: COEN240/Release-2/Yuhang/IMG_8533.HEIC
# Saved face: COEN240/face/Yuhang/week2-1_face0.png
# Saved face: COEN240/face/Yuhang/yuhang_li_face0.png
# Processing directory: COEN240/Release-2/Ruthu
# Saved face: COEN240/face/Ruthu/ML5(3)_face0.jpeg
# Saved face: COEN240/face/Ruthu/ML3_face0.jpeg
# Saved face: COEN240/face/Ruthu/ML4_face0.jpeg
# Error loading image: COEN240/Release-2/Ruthu/IMG_8543.HEIC
# Saved face: COEN240/face/Ruthu/ML8_face0.jpeg
# Saved face: COEN240/face/Ruthu/ML1-1_face0.jpeg
# Saved face: COEN240/face/Ruthu/ML6_face0.jpeg
# Saved face: COEN240/face/Ruthu/ML2(1)_face0.jpeg
# Saved face: COEN240/face/Ruthu/ML7_face0.jpeg
# Processing directory: COEN240/Release-2/Haochen
# Saved face: COEN240/face/Haochen/Haochen_Han_W1652182-2_face0.jpeg
# Saved face: COEN240/face/Haochen/Haochen_Han_W1652182-5_face0.jpeg
# Saved face: COEN240/face/Haochen/Haochen_Han_W1652182_face0.jpeg
# Error loading image: COEN240/Release-2/Haochen/IMG_8535.HEIC
# Saved face: COEN240/face/Haochen/Haochen_Han_W1652182-4_face0.jpeg
# Saved face: COEN240/face/Haochen/Haochen_Han_W1652182-7_face0.jpeg
# Saved face: COEN240/face/Haochen/Haochen_Han_W1652182-6_face0.jpeg
# Saved face: COEN240/face/Haochen/Haochen_Han_W1652182-1_face0.jpeg
# Processing directory: COEN240/Release-2/Dheeraj
# Saved face: COEN240/face/Dheeraj/Dheeraj_cropped_09-26_1_face0.jpeg
# Saved face: COEN240/face/Dheeraj/Dheeraj_cropped_09-26_1_face1.jpeg
# Saved face: COEN240/face/Dheeraj/Dheeraj_cropped_01_face0.jpeg
# Saved face: COEN240/face/Dheeraj/Dheeraj_cropped_09-28_3_face0.jpeg
# Saved face: COEN240/face/Dheeraj/Dheeraj_cropped_09-21_1_face0.jpeg
# Saved face: COEN240/face/Dheeraj/IMG_8407_face0.jpeg
# Saved face: COEN240/face/Dheeraj/IMG_8373_face0.jpeg
# Error loading image: COEN240/Release-2/Dheeraj/IMG_8566.HEIC
# Processing directory: COEN240/Release-2/Haisong
# Saved face: COEN240/face/Haisong/Haisong Wang_face0.png
# Saved face: COEN240/face/Haisong/9_face0.png
# Error loading image: COEN240/Release-2/Haisong/IMG_8538.HEIC
# Saved face: COEN240/face/Haisong/IMG_8403_face0.jpeg
# Saved face: COEN240/face/Haisong/IMG_8480_face0.jpeg
# Saved face: COEN240/face/Haisong/IMG_8243 (1)_face0.jpeg
# Saved face: COEN240/face/Haisong/IMG_8373 (1)_face0.jpeg
# Saved face: COEN240/face/Haisong/IMG_8271 (1)_face0.jpeg
# Saved face: COEN240/face/Haisong/Haisong Wang_face0.jpeg
# Processing directory: COEN240/Release-2/Prachi
# Saved face: COEN240/face/Prachi/1003_4_face0.png
# Saved face: COEN240/face/Prachi/Screenshot 2023-10-17 at 10.29.35 PM_face0.png
# Saved face: COEN240/face/Prachi/Screenshot 2023-09-24 at 3.36.30 PM_face0.png
# Saved face: COEN240/face/Prachi/Screenshot 2023-09-21 at 8.30.22 AM_face0.png
# Saved face: COEN240/face/Prachi/Screenshot 2023-10-17 at 10.29.28 PM_face0.png
# Error loading image: COEN240/Release-2/Prachi/IMG_8551.HEIC
# Saved face: COEN240/face/Prachi/Screenshot 2023-10-19 at 5.07.05 PM_face0.png
# Face extraction completed.
# Moved augmented data to final directory.
# Final output directory: COEN240/trainn/
